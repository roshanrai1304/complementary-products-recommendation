# %%
# !pip install pandasql
# !pip install qgrid
# !pip install numpy 
# !pip install pandas

# %%
import numpy as np
import pandas as pd
from pandasql import sqldf
df_orders = pd.read_csv(r'C:\Users\monik\OneDrive\Documents\innstacart-market\order_products__prior.csv')
df_orders.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_orders.shape
# len(df_orders.order_id.unique())
df_product = pd.read_csv(r"C:\Users\monik\OneDrive\Documents\innstacart-market\products.csv")
df_product.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
print(df_product.shape)
df_dept = pd.read_csv(r"C:\Users\monik\OneDrive\Documents\innstacart-market\departments.csv")
print(df_dept.shape)
df_dept.head(25)
# Out:
# (49688, 4)
# (21, 2)
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing

# %%
query = """
            select
                  a.order_id,
                  a.product_id,
                  b.department_id
            from
                df_orders a
            join
                df_product b
            on 
                a.product_id = b.product_id
                
        """
df_orders_detailed = sqldf(query, globals())
df_orders_detailed.head()
# Out:
#    order_id  product_id  department_id
# 0         2       33120             16
# 1         2       28985              4
# 2         2        9327             13
# 3         2       45918             13
# 4         2       30035             13

# %%
df_orders_detailed.shape
df_items = df_orders_detailed[df_orders_detailed['department_id'].isin([1,3,4,7,13,14,16,19,20])]
df_items.shape
# Out:
# (27520600, 3)

# %%
query = """
            select
                  product_id1,
                  department_id1,
                  product_id2,
                  department_id2,
                  count(*) as cnt
            from
            (
                select a.product_id as product_id1,
                       a.department_id as department_id1,
                       b.product_id as product_id2,
                       b.department_id as department_id2
                from 
                       df_items a
                join
                       df_items b
                on 
                       a.order_id = b.order_id
            ) a
            where
                product_id1 < product_id2
            and 
                department_id1 != department_id2
            group by
                product_id1,
                department_id1,
                product_id2,
                department_id2
            order by cnt desc
                
        """
df_grouped = sqldf(query, globals())

# %%
df_grouped.head()
# Out:
#    product_id1  department_id1  product_id2  department_id2    cnt
# 0        24852               4        27845              16  31641
# 1        13176               4        27845              16  26481
# 2        21137               4        27845              16  23813
# 3        24852               4        30489              20  18210
# 4        21903               4        27845              16  16944

# %%
df_grouped.shape
# Out:
# (19124682, 5)

# %%
query = """
            select
                  a.product_id1,
                  a.product_id2,
                  a.product_name1,
                  b.product_name as product_name2,
                  a.department_id1,
                  a.department_id2,
                  a.cnt
            from
            (
                select
                    a.product_id1,
                    a.product_id2,
                    b.product_name as product_name1,
                    a.department_id1,
                    a.department_id2,
                    a.cnt
                from
                    (select * from df_grouped) a
                join
                    (select * from df_product) b
                on 
                    a.product_id1 = b.product_id
                and
                    a.department_id1 = b.department_id
            ) a
            join
                (select * from df_product) b
            on
                a.product_id2 = b.product_id
            and
                a.department_id2 = b.department_id
        """

# %%
df_grouped_detailed = sqldf(query,globals())
df_grouped_detailed.head()
# Out:
#    product_id1  product_id2           product_name1       product_name2  \
# 0        24852        27845                  Banana  Organic Whole Milk
# 1        13176        27845  Bag of Organic Bananas  Organic Whole Milk
# 2        21137        27845    Organic Strawberries  Organic Whole Milk
# 3        24852        30489                  Banana     Original Hummus
# 4        21903        27845    Organic Baby Spinach  Organic Whole Milk
#
#    department_id1  department_id2    cnt
# 0               4              16  31641
# 1               4              16  26481
# 2               4              16  23813
# 3               4              20  18210
# 4               4              16  16944

# %%
df_grouped_detailed.tail()
# Out:
#           product_id1  product_id2                     product_name1  \
# 19124677        49644        49678                     Feta Crumbles
# 19124678        49644        49680                     Feta Crumbles
# 19124679        49654        49683  Teriyaki Sauce, Sesame, Original
# 19124680        49671        49683              Milk Chocolate Drops
# 19124681        49683        49685                    Cucumber Kirby
#
#                                product_name2  department_id1  department_id2  \
# 19124677     Large Chicken & Cheese Taquitos              16               1
# 19124678  All Natural Creamy Caesar Dressing              16              13
# 19124679                      Cucumber Kirby              13               4
# 19124680                      Cucumber Kirby              19               4
# 19124681  En Croute Roast Hazelnut Cranberry               4               1
#
#           cnt
# 19124677    1
# 19124678    1
# 19124679    1
# 19124680    1
# 19124681    1

# %%
df_grouped_detailed.shape
# Out:
# (19124682, 7)

# %%
df_grouped_detailed[(df_grouped_detailed['department_id1']!=4) & (df_grouped_detailed['department_id2']!=4)].shape
# Out:
# (14160692, 7)

# %%
df_grouped_detailed[(df_grouped_detailed['department_id1']!=4) & (df_grouped_detailed['department_id2']!=4)].head()
# Out:
#      product_id1  product_id2                product_name1  \
# 140        27845        30489           Organic Whole Milk
# 286        27845        44632           Organic Whole Milk
# 294        22035        30489  Organic Whole String Cheese
# 332        27086        44632                  Half & Half
# 351        30489        44632              Original Hummus
#
#                   product_name2  department_id1  department_id2   cnt
# 140             Original Hummus              16              20  6020
# 286  Sparkling Water Grapefruit              16               7  4374
# 294             Original Hummus              16              20  4332
# 332  Sparkling Water Grapefruit              16               7  4105
# 351  Sparkling Water Grapefruit              20               7  3999

# %%
query = """
            select 
                product_id,
                count(*) as cnt
            from
                df_orders
            group by
                product_id
        """

# %%
df_product_bought_count = sqldf(query,globals())
df_product_bought_count.head()
# Out:
#    product_id   cnt
# 0           1  1852
# 1           2    90
# 2           3   277
# 3           4   329
# 4           5    15

# %%
df_grouped_detailed_sample = df_grouped_detailed.head(50)
df_grouped_detailed_sample.head()
# Out:
#    product_id1  product_id2           product_name1       product_name2  \
# 0        24852        27845                  Banana  Organic Whole Milk
# 1        13176        27845  Bag of Organic Bananas  Organic Whole Milk
# 2        21137        27845    Organic Strawberries  Organic Whole Milk
# 3        24852        30489                  Banana     Original Hummus
# 4        21903        27845    Organic Baby Spinach  Organic Whole Milk
#
#    department_id1  department_id2    cnt
# 0               4              16  31641
# 1               4              16  26481
# 2               4              16  23813
# 3               4              20  18210
# 4               4              16  16944

# %%
df_product_bought_count_sample = df_product_bought_count.head(10)
df_product_bought_count_sample.head()
# Out:
#    product_id   cnt
# 0           1  1852
# 1           2    90
# 2           3   277
# 3           4   329
# 4           5    15

# %%
query = """
            select 
                product_id1,
                product_id2,
                product_name1,
                product_name2,
                department_id1,
                department_id2,
                cnt as item_intersection,
                cnt1+cnt2-cnt as item_union,
                (cnt*1.0)/(cnt1+cnt2-cnt) as ratio
                from
               (select 
                    a.*,
                    b.cnt as cnt2
                from
                    (select 
                        a.*,
                        b.cnt as cnt1
                    from
                        (select * from df_grouped_detailed_sample) a
                    join
                        (select * from df_product_bought_count_sample) b
                    on
                        a.product_id1 = b.product_id) a
                join
                    (select * from df_product_bought_count_sample) b
                on
                    a.product_id2 = b.product_id) a
        """
df_tmp = sqldf(query,globals())

# %%
df_tmp.head()
# Out:
# Empty DataFrame
# Columns: [product_id1, product_id2, product_name1, product_name2, department_id1, department_id2, item_intersection, item_union, ratio]
# Index: []

# %%
query = """
            select 
                product_id1,
                product_id2,
                product_name1,
                product_name2,
                department_id1,
                department_id2,
                cnt as item_intersection,
                cnt1+cnt2-cnt as item_union,
                (cnt*1.0)/(cnt1+cnt2-cnt) as ratio
                from
                    (select 
                        a.*,
                        b.cnt as cnt2
                    from
                        (select 
                            a.*,
                            b.cnt as cnt1
                        from
                            (select * from df_grouped_detailed) a
                        join
                            (select * from df_product_bought_count) b
                        on
                            a.product_id1 = b.product_id) a
                    join
                        (select * from df_product_bought_count) b
                    on
                        a.product_id2 = b.product_id) a

        """

# %%
df_ratio = sqldf(query,globals())
df_ratio.head()
# Out:
#    product_id1  product_id2           product_name1       product_name2  \
# 0        24852        27845                  Banana  Organic Whole Milk
# 1        13176        27845  Bag of Organic Bananas  Organic Whole Milk
# 2        21137        27845    Organic Strawberries  Organic Whole Milk
# 3        24852        30489                  Banana     Original Hummus
# 4        21903        27845    Organic Baby Spinach  Organic Whole Milk
#
#    department_id1  department_id2  item_intersection  item_union     ratio
# 0               4              16              31641      578829  0.054664
# 1               4              16              26481      490874  0.053947
# 2               4              16              23813      378775  0.062868
# 3               4              20              18210      525669  0.034642
# 4               4              16              16944      362882  0.046693

# %%
df_ratio_sorted = df_ratio.sort_values('ratio',ascending=False)

# %%
# !jupyter nbextension enable --py --sys-prefix qgrid
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
# Enabling notebook extension qgrid/extension...
#       - Validating: ok
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
import qgrid

# %%
df_ratio_sorted[df_ratio_sorted.item_union > 500].head(50)
# Out:
#         product_id1  product_id2  \
# 2657          13269        44786
# 5497           6508        44786
# 7904          44786        48747
# 43714         13029        13287
# 20181         19005        36849
# 32274         36496        44786
# 139411         1080        33016
# 66042         21567        45977
# 77673         13287        33016
# 183973        11961        48390
# 214067         5351        32921
# 204540         8958        10031
# 277337        19987        30337
# 328442        19318        35496
# 255498        10031        13573
# 107275        24857        28242
# 330880        35496        47552
# 180902         7205        48716
# 2719          11759        21573
# 106000        18205        45977
# 15177         25952        27356
# 66368         10351        25472
# 19820         19005        44245
# 402058        35169        47512
# 47546         25472        47873
# 418171        11163        43799
# 134846         5086        12240
# 706            6184        38928
# 76083         25472        29045
# 55554          8197        23282
# 352185        19318        35649
# 782            6184        37710
# 78294         13375        29103
# 55655         18070        25472
# 213057        32281        48716
# 382067        36988        47317
# 223757        30337        45977
# 343251        16305        41373
# 304654         5351        14334
# 305400         8496        23039
# 150603        14414        20641
# 556470        24243        33947
# 197929         7205        41458
# 457557        17295        32272
# 106419        35815        41458
# 562682         1481         9479
# 75735          5144        23282
# 449794        39293        48070
# 127628        10025        17462
# 2678          37710        38928
#
#                                             product_name1  \
# 2657    Oh My Yog! Pacific Coast Strawberry Trilayer Y...
# 5497       Oh My Yog! Madagascar Vanilla Trilayer Yogyurt
# 7904    Oh My Yog! Organic Wild Quebec Blueberry Cream...
# 43714               Ready Pac Salad Santa Fe Caesar Bowls
# 20181                             Jet-Puffed Marshmallows
# 32274           Oh My Yog! Trilayer Yogurt Apple Cinnamon
# 139411                                        Salad, Cobb
# 66042                     Blueberry Almond Breakfast Bars
# 77673                    Bistro Bowl Chicken Caesar Salad
# 183973                    Organic Nuts & Vanilla Beverage
# 214067                             Smoked Whitefish Salad
# 204540                                Danish Variety Pack
# 277337                      Breakfast Raspberry Chia Bars
# 328442                              SteviaClear Sweetener
# 255498                             Homestyle Orange Juice
# 107275        Raspberry Filmjolk Non-Fat Drinkable Yogurt
# 330880                       Real2 Alkalized Water 500 ml
# 180902                 Coconut Vanilla Creme Miracle Tart
# 2719                      Organic Simply Naked Pita Chips
# 106000           Peanut Butter Gluten Free Breakfast Bars
# 15177                               Original Potato Chips
# 66368          Sparkling Probiotic Drink Blueberry Cherry
# 19820                             Jet-Puffed Marshmallows
# 402058                                      Supreme Pizza
# 47546                 Sparkling Tangerine Probiotic Drink
# 418171                        Spicy Chik'n Veggie Patties
# 134846                Almondmilk, Pure, Chocolate Protein
# 706                                           Clementines
# 76083                 Sparkling Tangerine Probiotic Drink
# 55554       PlusShot Blueberry Acai Probiotic Juice Drink
# 352185                              SteviaClear Sweetener
# 782                                           Clementines
# 78294             Vitaminwater Zero Focus Kiwi-Strawberry
# 55655   Sparkling Probiotic Drink Strawberry Acai Coconut
# 213057                          Persian Lime Miracle Tart
# 382067                                       Low Salt Ham
# 223757    Gluten Free Dark Chocolate Cocoa Breakfast Bars
# 343251                                      Ritz Crackers
# 304654                             Smoked Whitefish Salad
# 305400                             Oat Bran Mini Pretzels
# 150603    Sandwich Cookies & Crackers Variety Snack Packs
# 556470                   Organic Diabetic Lifestyle Bread
# 197929                 Coconut Vanilla Creme Miracle Tart
# 457557          Country White Sour Dough Oval Sliced Loaf
# 106419  Dairy Free Gluten Free Chocolate Almond Butter...
# 562682                     Santa Fe Style Salad Cafe Bowl
# 75735                         Mango Probiotic Juice Drink
# 449794                Organic Soymilk Original Value Size
# 127628                     Freeze Dried Strawberry Slices
# 2678                                            Trail Mix
#
#                                             product_name2  department_id1  \
# 2657    Oh My Yog! Organic Wild Quebec Blueberry Cream...              16
# 5497    Oh My Yog! Organic Wild Quebec Blueberry Cream...              16
# 7904             Oh My Yog! Gingered Pear Trilayer Yogurt              19
# 43714                    Bistro Bowl Chicken Caesar Salad              20
# 20181                           Milk Chocolate Candy Bars              13
# 32274   Oh My Yog! Organic Wild Quebec Blueberry Cream...              16
# 139411                                         Chef Salad               4
# 66042   Breakfast Honey Oat Gluten Free Non GMO 5 Supe...              14
# 77673                                          Chef Salad               4
# 183973                  Organic Nuts & Chocolate Beverage               7
# 214067                          Wintermint Sugar Free Gum              20
# 204540                             Homestyle Orange Juice               3
# 277337    Gluten Free Dark Chocolate Cocoa Breakfast Bars              14
# 328442                       Real2 Alkalized Water 500 ml              13
# 255498                              Mini Butter Croissant               7
# 107275                 Drinkable Blueberry Non-Fat Yogurt               7
# 330880                  Sweet Drops SteviaClear Sweetener               7
# 180902                           Meyer Lemon Miracle Tart              19
# 2719                              Roasted Pine Nut Hummus              19
# 106000  Breakfast Honey Oat Gluten Free Non GMO 5 Supe...              14
# 15177                                    French Onion Dip              19
# 66368                 Sparkling Tangerine Probiotic Drink               7
# 19820                          Honey Maid Graham Crackers              13
# 402058                                  Lite Energy Drink               1
# 47546             Sparkling Probiotic Drink Mango Coconut              16
# 418171  Natural Low Moisture Part Skim Mozzarella Chee...               1
# 134846                        Vanilla Protein Almond Milk               7
# 706                              0% Greek Strained Yogurt               4
# 76083    Organic Hibiscus Berry Sparkling Probiotic Drink              16
# 55554           PlusShot Strawberry Probiotic Juice Drink               7
# 352185                                    Alkalized Water              13
# 782                                             Trail Mix               4
# 78294                Zero Go-Go Mixed Berry Vitamin Water               1
# 55655                 Sparkling Tangerine Probiotic Drink               7
# 213057                           Meyer Lemon Miracle Tart              19
# 382067                              Imported Swiss Cheese              20
# 223757  Breakfast Honey Oat Gluten Free Non GMO 5 Supe...              19
# 343251  Original Smooth Style Strawberry Flavored Low ...              19
# 304654                                 Fruit & Nut Medley              20
# 305400                              Fat Free Cream Cheese              19
# 150603                             Pop Tarts Variety Pack              19
# 556470                        Cranberry Nectar 100% Juice               3
# 197929                             Chocolate Miracle Tart              19
# 457557         Low-Fat Apricot on the Bottom Greek Yogurt               3
# 106419                             Chocolate Miracle Tart              19
# 562682                               Ham & Swiss Sandwich               4
# 75735           PlusShot Strawberry Probiotic Juice Drink               7
# 449794                   Chocolate Mint Crisp Protein Bar              16
# 127628                           Freeze Dried Blueberries               1
# 2678                             0% Greek Strained Yogurt              19
#
#         department_id2  item_intersection  item_union     ratio
# 2657                19               1502        3627  0.414116
# 5497                19                984        3857  0.255121
# 7904                16                787        3238  0.243051
# 43714                4                254        1791  0.141820
# 20181               19                436        3296  0.132282
# 32274               19                316        2569  0.123005
# 139411              20                105         933  0.112540
# 66042                3                188        1687  0.111440
# 77673               20                166        1616  0.102723
# 183973              19                 84         846  0.099291
# 214067              19                 74         751  0.098535
# 204540               7                 77         788  0.097716
# 277337              19                 60         625  0.096000
# 328442               7                 52         574  0.090592
# 255498               3                 64         754  0.084881
# 107275              16                130        1542  0.084306
# 330880              13                 52         632  0.082278
# 180902               3                 85        1036  0.082046
# 2719                20               1483       18855  0.078653
# 106000               3                131        1667  0.078584
# 15177               20                526        6718  0.078297
# 66368               16                187        2451  0.076295
# 19820               19                441        5783  0.076258
# 402058               7                 44         583  0.075472
# 47546                7                239        3209  0.074478
# 418171              16                 42         564  0.074468
# 134846              16                108        1490  0.072483
# 706                 16               2905       41176  0.070551
# 76083                7                169        2400  0.070417
# 55554               16                213        3076  0.069246
# 352185               7                 49         708  0.069209
# 782                 19               2767       40144  0.068927
# 78294                7                165        2420  0.068182
# 55655               16                213        3141  0.067813
# 213057               3                 75        1106  0.067812
# 382067              16                 46         687  0.066958
# 223757               3                 72        1082  0.066543
# 343251              16                 50         753  0.066401
# 304654              19                 55         831  0.066185
# 305400              16                 55         832  0.066106
# 150603              14                 99        1498  0.066088
# 556470               7                 33         505  0.065347
# 197929               3                 79        1227  0.064385
# 457557              16                 39         608  0.064145
# 106419               3                131        2048  0.063965
# 562682              20                 32         501  0.063872
# 75735               16                169        2648  0.063822
# 449794              19                 40         628  0.063694
# 127628              19                113        1776  0.063626
# 2678                16               1497       23809  0.062875
